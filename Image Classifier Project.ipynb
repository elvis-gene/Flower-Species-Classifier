# %%
# Author: Elvis Presley Gene
# Date: 21 - jan - 2020

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
#DONE: Imports 
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from collections import OrderedDict
from workspace_utils import active_session
import time
import json
from PIL import Image
import numpy as np
from torch.autograd import Variable
import seaborn as sns

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# DONE: Define your transforms for the training, validation, and testing sets

data_transforms = {'train_transforms': transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])]), 
                       
                      'test_transforms': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])]),
                       
                      'valid_transforms': transforms.Compose([transforms.Resize(256),
                                            transforms.CenterCrop(224),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.406], 
                                                                 [0.229, 0.224, 0.225])])}

# Done: Load the datasets with ImageFolder
image_datasets = {'train_data': datasets.ImageFolder(train_dir, transform=data_transforms['train_transforms']),
                     'test_data': datasets.ImageFolder(test_dir, transform=data_transforms['test_transforms']),
                     'valid_data': datasets.ImageFolder(valid_dir, transform=data_transforms['valid_transforms'])}

# Done: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {'train_loader': torch.utils.data.DataLoader(image_datasets['train_data'], batch_size=32, shuffle=False),
                'test_loader': torch.utils.data.DataLoader(image_datasets['test_data'], batch_size=32, shuffle=False),
                'valid_loader':torch.utils.data.DataLoader(image_datasets['valid_data'], batch_size=32, shuffle=False)}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build network.

# Load a pretrained network.
model = models.vgg16(pretrained=True)

# Freeze parameters
for param in model.parameters():
    param.requires_grad = False

# Build a feed-forward network
classifier = nn.Sequential(
             nn.Linear(25088, 2304),
             nn.ReLU(),
             nn.Dropout(0.3),
             nn.Linear(2304, 1224),
             nn.ReLU(),
             nn.Dropout(0.3),
             nn.Linear(1224, 684),
             nn.ReLU(),
             nn.Dropout(0.3),
             nn.Linear(684, 302),
             nn.ReLU(),
             nn.Dropout(0.3),
             nn.Linear(302, 102),
             nn.LogSoftmax(dim=1))
    

model.classifier = classifier
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 102576307.65it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=2304, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3)
#     (3): Linear(in_features=2304, out_features=1224, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3)
#     (6): Linear(in_features=1224, out_features=684, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.3)
#     (9): Linear(in_features=684, out_features=302, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.3)
#     (12): Linear(in_features=302, out_features=102, bias=True)
#     (13): LogSoftmax()
#   )
# )

# %%
# DONE: Train your network
print("Training...")
optimizer = optim.Adam(model.classifier.parameters(), lr = 0.001) 
criterion = criterion = nn.NLLLoss()
device = 'cuda'
model.to(device)
epochs = 6
print_every = 5
steps = 0
valid_loss = 0
accuracy=0

with active_session():
# do long-running work here
    start = time.time()
    
    for e in range(epochs):
        running_loss = 0
        for i, (inputs, labels) in enumerate(dataloaders['train_loader']):
            steps += 1
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model.forward(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if steps % print_every == 0:
                model.eval()
                #  Training Loss and Training accuracy
                with torch.no_grad():
                        
                        outputs = model.forward(inputs)
                        train_loss = criterion(outputs, labels)
                        p = torch.exp(outputs).data
                        equal = (labels.data == p.max(dim=1)[1])
                        t_accuracy += equal.type(torch.FloatTensor).mean()
                
                train_loss = train_loss / len(dataloaders['train_loader'])
                t_accuracy = t_accuracy / len(dataloaders['train_loader'])
                        
                print("Epoch: {}/{}..".format(e + 1, epochs),
                      "Validation Loss: {:.3f}.. ".format(train_loss),
                      "Validation Accuracy: {:.3f}".format(t_accuracy))
                
                
                # Validation Loss and Validation accuracy
        for iii, (inputs_v, labels_v) in enumerate(dataloaders['valid_loader']):

            inputs_v, labels_v = inputs_v.to('cuda:0'), labels_v.to('cuda:0')
            model.to('cuda:0')

            if steps % print_every == 0:
                model.eval()
                
                with torch.no_grad():
                    #optimizer.zero_grad() #no backward pass
                    outputs_v = model.forward(inputs_v)
                    valid_loss = criterion(outputs_v, labels_v)
                    ps = torch.exp(outputs_v).data
                    equality = (labels_v.data == ps.max(dim=1)[1])
                    accuracy += equality.type(torch.FloatTensor).mean()

                valid_loss = valid_loss / len(dataloaders['valid_loader'])
                accuracy = accuracy / len(dataloaders['valid_loader'])

                print("Epoch: {}/{}..".format(e + 1, epochs),
                      "Validation Loss: {:.3f}.. ".format(valid_loss),
                      "Validation Accuracy: {:.3f}".format(accuracy))

                model.train() #To check latter if it should also be put on top...

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print("Done training and Testing!")
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# Training...
# Epoch: 1/10.. Validation Loss: 0.177..  Test Accuracy: 0.025
# Epoch: 1/10.. Validation Loss: 0.181..  Test Accuracy: 0.015
# Epoch: 1/10.. Validation Loss: 0.170..  Test Accuracy: 0.030
# Epoch: 1/10.. Validation Loss: 0.178..  Test Accuracy: 0.026
# Epoch: 1/10.. Validation Loss: 0.172..  Test Accuracy: 0.044
# Epoch: 1/10.. Validation Loss: 0.170..  Test Accuracy: 0.051
# Epoch: 1/10.. Validation Loss: 0.163..  Test Accuracy: 0.043
# Epoch: 1/10.. Validation Loss: 0.168..  Test Accuracy: 0.065
# Epoch: 1/10.. Validation Loss: 0.164..  Test Accuracy: 0.069
# Epoch: 1/10.. Validation Loss: 0.170..  Test Accuracy: 0.069
# Epoch: 1/10.. Validation Loss: 0.165..  Test Accuracy: 0.083
# Epoch: 1/10.. Validation Loss: 0.154..  Test Accuracy: 0.088
# Epoch: 1/10.. Validation Loss: 0.143..  Test Accuracy: 0.093
# Epoch: 1/10.. Validation Loss: 0.165..  Test Accuracy: 0.114
# Epoch: 1/10.. Validation Loss: 0.143..  Test Accuracy: 0.118
# Epoch: 1/10.. Validation Loss: 0.152..  Test Accuracy: 0.122
# Epoch: 1/10.. Validation Loss: 0.142..  Test Accuracy: 0.129
# Epoch: 1/10.. Validation Loss: 0.143..  Test Accuracy: 0.140
# Epoch: 1/10.. Validation Loss: 0.137..  Test Accuracy: 0.150
# Epoch: 1/10.. Validation Loss: 0.131..  Test Accuracy: 0.161
# Epoch: 1/10.. Validation Loss: 0.127..  Test Accuracy: 0.195
# Epoch: 1/10.. Validation Loss: 0.139..  Test Accuracy: 0.177
# Epoch: 1/10.. Validation Loss: 0.135..  Test Accuracy: 0.161
# Epoch: 1/10.. Validation Loss: 0.116..  Test Accuracy: 0.156
# Epoch: 1/10.. Validation Loss: 0.120..  Test Accuracy: 0.167
# Epoch: 1/10.. Validation Loss: 0.111..  Test Accuracy: 0.163
# Epoch: 1/10.. Validation Loss: 0.133..  Test Accuracy: 0.199
# Epoch: 1/10.. Validation Loss: 0.112..  Test Accuracy: 0.240
# Epoch: 1/10.. Validation Loss: 0.095..  Test Accuracy: 0.263
# Epoch: 1/10.. Validation Loss: 0.121..  Test Accuracy: 0.296
# Epoch: 1/10.. Validation Loss: 0.109..  Test Accuracy: 0.294
# Epoch: 1/10.. Validation Loss: 0.100..  Test Accuracy: 0.306
# Epoch: 1/10.. Validation Loss: 0.060..  Test Accuracy: 0.325
# Epoch: 1/10.. Validation Loss: 0.104..  Test Accuracy: 0.324
# Epoch: 1/10.. Validation Loss: 0.138..  Test Accuracy: 0.311
# Epoch: 1/10.. Validation Loss: 0.133..  Test Accuracy: 0.314
# Epoch: 1/10.. Validation Loss: 0.122..  Test Accuracy: 0.321
# Epoch: 1/10.. Validation Loss: 0.103..  Test Accuracy: 0.301
# Epoch: 1/10.. Validation Loss: 0.115..  Test Accuracy: 0.315
# Epoch: 1/10.. Validation Loss: 0.085..  Test Accuracy: 0.362
# Epoch: 1/10.. Validation Loss: 0.109..  Test Accuracy: 0.332
# Epoch: 2/10.. Validation Loss: 0.097..  Test Accuracy: 0.387
# Epoch: 2/10.. Validation Loss: 0.096..  Test Accuracy: 0.377
# Epoch: 2/10.. Validation Loss: 0.096..  Test Accuracy: 0.369
# Epoch: 2/10.. Validation Loss: 0.094..  Test Accuracy: 0.389
# Epoch: 2/10.. Validation Loss: 0.104..  Test Accuracy: 0.395
# Epoch: 2/10.. Validation Loss: 0.070..  Test Accuracy: 0.359
# Epoch: 2/10.. Validation Loss: 0.101..  Test Accuracy: 0.361
# Epoch: 2/10.. Validation Loss: 0.069..  Test Accuracy: 0.397
# Epoch: 2/10.. Validation Loss: 0.075..  Test Accuracy: 0.394
# Epoch: 2/10.. Validation Loss: 0.084..  Test Accuracy: 0.411
# Epoch: 2/10.. Validation Loss: 0.095..  Test Accuracy: 0.407
# Epoch: 2/10.. Validation Loss: 0.079..  Test Accuracy: 0.395
# Epoch: 2/10.. Validation Loss: 0.089..  Test Accuracy: 0.413
# Epoch: 2/10.. Validation Loss: 0.100..  Test Accuracy: 0.425
# Epoch: 2/10.. Validation Loss: 0.067..  Test Accuracy: 0.400
# Epoch: 2/10.. Validation Loss: 0.087..  Test Accuracy: 0.434
# Epoch: 2/10.. Validation Loss: 0.112..  Test Accuracy: 0.423
# Epoch: 2/10.. Validation Loss: 0.109..  Test Accuracy: 0.422
# Epoch: 2/10.. Validation Loss: 0.065..  Test Accuracy: 0.425
# Epoch: 2/10.. Validation Loss: 0.083..  Test Accuracy: 0.441
# Epoch: 2/10.. Validation Loss: 0.097..  Test Accuracy: 0.431
# Epoch: 2/10.. Validation Loss: 0.061..  Test Accuracy: 0.456
# Epoch: 2/10.. Validation Loss: 0.090..  Test Accuracy: 0.446
# Epoch: 2/10.. Validation Loss: 0.076..  Test Accuracy: 0.447
# Epoch: 2/10.. Validation Loss: 0.057..  Test Accuracy: 0.423
# Epoch: 2/10.. Validation Loss: 0.074..  Test Accuracy: 0.452
# Epoch: 2/10.. Validation Loss: 0.065..  Test Accuracy: 0.458
# Epoch: 2/10.. Validation Loss: 0.095..  Test Accuracy: 0.469
# Epoch: 2/10.. Validation Loss: 0.071..  Test Accuracy: 0.497
# Epoch: 2/10.. Validation Loss: 0.101..  Test Accuracy: 0.501
# Epoch: 2/10.. Validation Loss: 0.092..  Test Accuracy: 0.446
# Epoch: 2/10.. Validation Loss: 0.058..  Test Accuracy: 0.484
# Epoch: 2/10.. Validation Loss: 0.082..  Test Accuracy: 0.510
# Epoch: 2/10.. Validation Loss: 0.088..  Test Accuracy: 0.516
# Epoch: 2/10.. Validation Loss: 0.082..  Test Accuracy: 0.496
# Epoch: 2/10.. Validation Loss: 0.042..  Test Accuracy: 0.510
# Epoch: 2/10.. Validation Loss: 0.075..  Test Accuracy: 0.520
# Epoch: 2/10.. Validation Loss: 0.078..  Test Accuracy: 0.530
# Epoch: 2/10.. Validation Loss: 0.071..  Test Accuracy: 0.531
# Epoch: 2/10.. Validation Loss: 0.080..  Test Accuracy: 0.499
# Epoch: 2/10.. Validation Loss: 0.068..  Test Accuracy: 0.487
# Epoch: 3/10.. Validation Loss: 0.070..  Test Accuracy: 0.484
# Epoch: 3/10.. Validation Loss: 0.068..  Test Accuracy: 0.467
# Epoch: 3/10.. Validation Loss: 0.085..  Test Accuracy: 0.472
# Epoch: 3/10.. Validation Loss: 0.073..  Test Accuracy: 0.476
# Epoch: 3/10.. Validation Loss: 0.069..  Test Accuracy: 0.484
# Epoch: 3/10.. Validation Loss: 0.084..  Test Accuracy: 0.523
# Epoch: 3/10.. Validation Loss: 0.082..  Test Accuracy: 0.518
# Epoch: 3/10.. Validation Loss: 0.067..  Test Accuracy: 0.534
# Epoch: 3/10.. Validation Loss: 0.076..  Test Accuracy: 0.535
# Epoch: 3/10.. Validation Loss: 0.060..  Test Accuracy: 0.549
# Epoch: 3/10.. Validation Loss: 0.093..  Test Accuracy: 0.496
# Epoch: 3/10.. Validation Loss: 0.062..  Test Accuracy: 0.510
# Epoch: 3/10.. Validation Loss: 0.073..  Test Accuracy: 0.498
# Epoch: 3/10.. Validation Loss: 0.092..  Test Accuracy: 0.529
# Epoch: 3/10.. Validation Loss: 0.072..  Test Accuracy: 0.553
# Epoch: 3/10.. Validation Loss: 0.078..  Test Accuracy: 0.536
# Epoch: 3/10.. Validation Loss: 0.082..  Test Accuracy: 0.550
# Epoch: 3/10.. Validation Loss: 0.066..  Test Accuracy: 0.542
# Epoch: 3/10.. Validation Loss: 0.062..  Test Accuracy: 0.563
# Epoch: 3/10.. Validation Loss: 0.072..  Test Accuracy: 0.566
# Epoch: 3/10.. Validation Loss: 0.074..  Test Accuracy: 0.571
# Epoch: 3/10.. Validation Loss: 0.083..  Test Accuracy: 0.594
# Epoch: 3/10.. Validation Loss: 0.067..  Test Accuracy: 0.596
# Epoch: 3/10.. Validation Loss: 0.056..  Test Accuracy: 0.607
# Epoch: 3/10.. Validation Loss: 0.065..  Test Accuracy: 0.583
# Epoch: 3/10.. Validation Loss: 0.062..  Test Accuracy: 0.580
# Epoch: 3/10.. Validation Loss: 0.084..  Test Accuracy: 0.593
# Epoch: 3/10.. Validation Loss: 0.054..  Test Accuracy: 0.586
# Epoch: 3/10.. Validation Loss: 0.080..  Test Accuracy: 0.563
# Epoch: 3/10.. Validation Loss: 0.069..  Test Accuracy: 0.581
# Epoch: 3/10.. Validation Loss: 0.058..  Test Accuracy: 0.558
# Epoch: 3/10.. Validation Loss: 0.090..  Test Accuracy: 0.578
# Epoch: 3/10.. Validation Loss: 0.038..  Test Accuracy: 0.584
# Epoch: 3/10.. Validation Loss: 0.039..  Test Accuracy: 0.573
# Epoch: 3/10.. Validation Loss: 0.065..  Test Accuracy: 0.562
# Epoch: 3/10.. Validation Loss: 0.068..  Test Accuracy: 0.576
# Epoch: 3/10.. Validation Loss: 0.085..  Test Accuracy: 0.597
# Epoch: 3/10.. Validation Loss: 0.076..  Test Accuracy: 0.591
# Epoch: 3/10.. Validation Loss: 0.098..  Test Accuracy: 0.589
# Epoch: 3/10.. Validation Loss: 0.039..  Test Accuracy: 0.580
# Epoch: 3/10.. Validation Loss: 0.040..  Test Accuracy: 0.598
# Epoch: 4/10.. Validation Loss: 0.055..  Test Accuracy: 0.586
# Epoch: 4/10.. Validation Loss: 0.059..  Test Accuracy: 0.591
# Epoch: 4/10.. Validation Loss: 0.068..  Test Accuracy: 0.608
# Epoch: 4/10.. Validation Loss: 0.033..  Test Accuracy: 0.616
# Epoch: 4/10.. Validation Loss: 0.060..  Test Accuracy: 0.617
# Epoch: 4/10.. Validation Loss: 0.052..  Test Accuracy: 0.604
# Epoch: 4/10.. Validation Loss: 0.048..  Test Accuracy: 0.609
# Epoch: 4/10.. Validation Loss: 0.066..  Test Accuracy: 0.629
# Epoch: 4/10.. Validation Loss: 0.061..  Test Accuracy: 0.642
# Epoch: 4/10.. Validation Loss: 0.064..  Test Accuracy: 0.610
# Epoch: 4/10.. Validation Loss: 0.084..  Test Accuracy: 0.595
# Epoch: 4/10.. Validation Loss: 0.046..  Test Accuracy: 0.593
# Epoch: 4/10.. Validation Loss: 0.051..  Test Accuracy: 0.598
# Epoch: 4/10.. Validation Loss: 0.037..  Test Accuracy: 0.594
# Epoch: 4/10.. Validation Loss: 0.079..  Test Accuracy: 0.597
# Epoch: 4/10.. Validation Loss: 0.057..  Test Accuracy: 0.599
# Epoch: 4/10.. Validation Loss: 0.070..  Test Accuracy: 0.625
# Epoch: 4/10.. Validation Loss: 0.049..  Test Accuracy: 0.584
# Epoch: 4/10.. Validation Loss: 0.027..  Test Accuracy: 0.639
# Epoch: 4/10.. Validation Loss: 0.056..  Test Accuracy: 0.631
# Epoch: 4/10.. Validation Loss: 0.062..  Test Accuracy: 0.593
# Epoch: 4/10.. Validation Loss: 0.059..  Test Accuracy: 0.628
# Epoch: 4/10.. Validation Loss: 0.035..  Test Accuracy: 0.649
# Epoch: 4/10.. Validation Loss: 0.064..  Test Accuracy: 0.649
# Epoch: 4/10.. Validation Loss: 0.057..  Test Accuracy: 0.633
# Epoch: 4/10.. Validation Loss: 0.110..  Test Accuracy: 0.639
# Epoch: 4/10.. Validation Loss: 0.061..  Test Accuracy: 0.635
# Epoch: 4/10.. Validation Loss: 0.050..  Test Accuracy: 0.659
# Epoch: 4/10.. Validation Loss: 0.041..  Test Accuracy: 0.659
# Epoch: 4/10.. Validation Loss: 0.052..  Test Accuracy: 0.651
# Epoch: 4/10.. Validation Loss: 0.036..  Test Accuracy: 0.669
# Epoch: 4/10.. Validation Loss: 0.054..  Test Accuracy: 0.668
# Epoch: 4/10.. Validation Loss: 0.041..  Test Accuracy: 0.670
# Epoch: 4/10.. Validation Loss: 0.055..  Test Accuracy: 0.673
# Epoch: 4/10.. Validation Loss: 0.032..  Test Accuracy: 0.660
# Epoch: 4/10.. Validation Loss: 0.081..  Test Accuracy: 0.652
# Epoch: 4/10.. Validation Loss: 0.043..  Test Accuracy: 0.657
# Epoch: 4/10.. Validation Loss: 0.053..  Test Accuracy: 0.655
# Epoch: 4/10.. Validation Loss: 0.031..  Test Accuracy: 0.670
# Epoch: 4/10.. Validation Loss: 0.041..  Test Accuracy: 0.677
# Epoch: 4/10.. Validation Loss: 0.043..  Test Accuracy: 0.675
# Epoch: 5/10.. Validation Loss: 0.049..  Test Accuracy: 0.678
# Epoch: 5/10.. Validation Loss: 0.062..  Test Accuracy: 0.673
# Epoch: 5/10.. Validation Loss: 0.047..  Test Accuracy: 0.686
# Epoch: 5/10.. Validation Loss: 0.044..  Test Accuracy: 0.703
# Epoch: 5/10.. Validation Loss: 0.052..  Test Accuracy: 0.696
# Epoch: 5/10.. Validation Loss: 0.041..  Test Accuracy: 0.702
# Epoch: 5/10.. Validation Loss: 0.064..  Test Accuracy: 0.688
# Epoch: 5/10.. Validation Loss: 0.071..  Test Accuracy: 0.672
# Epoch: 5/10.. Validation Loss: 0.028..  Test Accuracy: 0.683
# Epoch: 5/10.. Validation Loss: 0.015..  Test Accuracy: 0.665
# Epoch: 5/10.. Validation Loss: 0.044..  Test Accuracy: 0.655
# Epoch: 5/10.. Validation Loss: 0.019..  Test Accuracy: 0.650
# Epoch: 5/10.. Validation Loss: 0.054..  Test Accuracy: 0.664
# Epoch: 5/10.. Validation Loss: 0.039..  Test Accuracy: 0.681
# Epoch: 5/10.. Validation Loss: 0.015..  Test Accuracy: 0.696
# Epoch: 5/10.. Validation Loss: 0.039..  Test Accuracy: 0.677
# Epoch: 5/10.. Validation Loss: 0.044..  Test Accuracy: 0.659
# Epoch: 5/10.. Validation Loss: 0.048..  Test Accuracy: 0.646
# Epoch: 5/10.. Validation Loss: 0.100..  Test Accuracy: 0.671
# Epoch: 5/10.. Validation Loss: 0.051..  Test Accuracy: 0.679
# Epoch: 5/10.. Validation Loss: 0.086..  Test Accuracy: 0.670
# Epoch: 5/10.. Validation Loss: 0.057..  Test Accuracy: 0.678
# Epoch: 5/10.. Validation Loss: 0.065..  Test Accuracy: 0.655
# Epoch: 5/10.. Validation Loss: 0.040..  Test Accuracy: 0.684
# Epoch: 5/10.. Validation Loss: 0.052..  Test Accuracy: 0.711
# Epoch: 5/10.. Validation Loss: 0.045..  Test Accuracy: 0.703
# Epoch: 5/10.. Validation Loss: 0.060..  Test Accuracy: 0.684
# Epoch: 5/10.. Validation Loss: 0.076..  Test Accuracy: 0.660
# Epoch: 5/10.. Validation Loss: 0.030..  Test Accuracy: 0.665
# Epoch: 5/10.. Validation Loss: 0.079..  Test Accuracy: 0.675
# Epoch: 5/10.. Validation Loss: 0.046..  Test Accuracy: 0.686
# Epoch: 5/10.. Validation Loss: 0.052..  Test Accuracy: 0.688
# Epoch: 5/10.. Validation Loss: 0.039..  Test Accuracy: 0.693
# Epoch: 5/10.. Validation Loss: 0.047..  Test Accuracy: 0.694
# Epoch: 5/10.. Validation Loss: 0.042..  Test Accuracy: 0.695
# Epoch: 5/10.. Validation Loss: 0.037..  Test Accuracy: 0.683
# Epoch: 5/10.. Validation Loss: 0.053..  Test Accuracy: 0.679
# Epoch: 5/10.. Validation Loss: 0.022..  Test Accuracy: 0.710
# Epoch: 5/10.. Validation Loss: 0.037..  Test Accuracy: 0.707
# Epoch: 5/10.. Validation Loss: 0.024..  Test Accuracy: 0.713
# Epoch: 5/10.. Validation Loss: 0.035..  Test Accuracy: 0.718
# Epoch: 6/10.. Validation Loss: 0.055..  Test Accuracy: 0.706
# Epoch: 6/10.. Validation Loss: 0.038..  Test Accuracy: 0.707
# Epoch: 6/10.. Validation Loss: 0.052..  Test Accuracy: 0.702
# Epoch: 6/10.. Validation Loss: 0.037..  Test Accuracy: 0.716
# Epoch: 6/10.. Validation Loss: 0.034..  Test Accuracy: 0.706
# Epoch: 6/10.. Validation Loss: 0.041..  Test Accuracy: 0.708
# Epoch: 6/10.. Validation Loss: 0.037..  Test Accuracy: 0.720
# Epoch: 6/10.. Validation Loss: 0.039..  Test Accuracy: 0.696
# Epoch: 6/10.. Validation Loss: 0.039..  Test Accuracy: 0.705
# Epoch: 6/10.. Validation Loss: 0.066..  Test Accuracy: 0.692
# Epoch: 6/10.. Validation Loss: 0.030..  Test Accuracy: 0.705
# Epoch: 6/10.. Validation Loss: 0.055..  Test Accuracy: 0.705
# Epoch: 6/10.. Validation Loss: 0.030..  Test Accuracy: 0.743
# Epoch: 6/10.. Validation Loss: 0.054..  Test Accuracy: 0.742
# Epoch: 6/10.. Validation Loss: 0.044..  Test Accuracy: 0.736
# Epoch: 6/10.. Validation Loss: 0.056..  Test Accuracy: 0.718
# Epoch: 6/10.. Validation Loss: 0.089..  Test Accuracy: 0.719
# Epoch: 6/10.. Validation Loss: 0.048..  Test Accuracy: 0.714
# Epoch: 6/10.. Validation Loss: 0.036..  Test Accuracy: 0.703
# Epoch: 6/10.. Validation Loss: 0.049..  Test Accuracy: 0.694
# Epoch: 6/10.. Validation Loss: 0.051..  Test Accuracy: 0.700
# Epoch: 6/10.. Validation Loss: 0.040..  Test Accuracy: 0.698
# Epoch: 6/10.. Validation Loss: 0.050..  Test Accuracy: 0.716
# Epoch: 6/10.. Validation Loss: 0.024..  Test Accuracy: 0.723
# Epoch: 6/10.. Validation Loss: 0.022..  Test Accuracy: 0.763
# Epoch: 6/10.. Validation Loss: 0.026..  Test Accuracy: 0.755
# Epoch: 6/10.. Validation Loss: 0.036..  Test Accuracy: 0.758
# Epoch: 6/10.. Validation Loss: 0.063..  Test Accuracy: 0.770
# Epoch: 6/10.. Validation Loss: 0.051..  Test Accuracy: 0.741
# Epoch: 6/10.. Validation Loss: 0.039..  Test Accuracy: 0.722
# Epoch: 6/10.. Validation Loss: 0.057..  Test Accuracy: 0.731
# Epoch: 6/10.. Validation Loss: 0.039..  Test Accuracy: 0.739
# Epoch: 6/10.. Validation Loss: 0.030..  Test Accuracy: 0.740
# Epoch: 6/10.. Validation Loss: 0.057..  Test Accuracy: 0.736
# Epoch: 6/10.. Validation Loss: 0.033..  Test Accuracy: 0.734
# Epoch: 6/10.. Validation Loss: 0.038..  Test Accuracy: 0.725
# Epoch: 6/10.. Validation Loss: 0.041..  Test Accuracy: 0.723
# Epoch: 6/10.. Validation Loss: 0.036..  Test Accuracy: 0.714
# Epoch: 6/10.. Validation Loss: 0.045..  Test Accuracy: 0.713
# Epoch: 6/10.. Validation Loss: 0.046..  Test Accuracy: 0.709
# Epoch: 6/10.. Validation Loss: 0.047..  Test Accuracy: 0.728
# Epoch: 7/10.. Validation Loss: 0.037..  Test Accuracy: 0.739
# Epoch: 7/10.. Validation Loss: 0.045..  Test Accuracy: 0.739
# Epoch: 7/10.. Validation Loss: 0.044..  Test Accuracy: 0.740
# Epoch: 7/10.. Validation Loss: 0.040..  Test Accuracy: 0.750
# Epoch: 7/10.. Validation Loss: 0.029..  Test Accuracy: 0.737
# Epoch: 7/10.. Validation Loss: 0.049..  Test Accuracy: 0.738
# Epoch: 7/10.. Validation Loss: 0.048..  Test Accuracy: 0.739
# Epoch: 7/10.. Validation Loss: 0.042..  Test Accuracy: 0.752
# Epoch: 7/10.. Validation Loss: 0.034..  Test Accuracy: 0.762
# Epoch: 7/10.. Validation Loss: 0.043..  Test Accuracy: 0.763
# Epoch: 7/10.. Validation Loss: 0.036..  Test Accuracy: 0.755
# Epoch: 7/10.. Validation Loss: 0.058..  Test Accuracy: 0.758
# Epoch: 7/10.. Validation Loss: 0.059..  Test Accuracy: 0.746
# Epoch: 7/10.. Validation Loss: 0.038..  Test Accuracy: 0.757
# Epoch: 7/10.. Validation Loss: 0.024..  Test Accuracy: 0.757
# Epoch: 7/10.. Validation Loss: 0.065..  Test Accuracy: 0.760
# Epoch: 7/10.. Validation Loss: 0.048..  Test Accuracy: 0.761
# Epoch: 7/10.. Validation Loss: 0.043..  Test Accuracy: 0.754
# Epoch: 7/10.. Validation Loss: 0.032..  Test Accuracy: 0.761
# Epoch: 7/10.. Validation Loss: 0.031..  Test Accuracy: 0.741
# Epoch: 7/10.. Validation Loss: 0.042..  Test Accuracy: 0.750
# Epoch: 7/10.. Validation Loss: 0.059..  Test Accuracy: 0.740
# Epoch: 7/10.. Validation Loss: 0.044..  Test Accuracy: 0.750
# Epoch: 7/10.. Validation Loss: 0.041..  Test Accuracy: 0.768
# Epoch: 7/10.. Validation Loss: 0.059..  Test Accuracy: 0.747
# Epoch: 7/10.. Validation Loss: 0.031..  Test Accuracy: 0.745
# Epoch: 7/10.. Validation Loss: 0.039..  Test Accuracy: 0.738
# Epoch: 7/10.. Validation Loss: 0.048..  Test Accuracy: 0.759
# Epoch: 7/10.. Validation Loss: 0.056..  Test Accuracy: 0.751
# Epoch: 7/10.. Validation Loss: 0.073..  Test Accuracy: 0.738
# Epoch: 7/10.. Validation Loss: 0.030..  Test Accuracy: 0.749
# Epoch: 7/10.. Validation Loss: 0.037..  Test Accuracy: 0.756
# Epoch: 7/10.. Validation Loss: 0.044..  Test Accuracy: 0.750
# Epoch: 7/10.. Validation Loss: 0.039..  Test Accuracy: 0.759
# Epoch: 7/10.. Validation Loss: 0.055..  Test Accuracy: 0.759
# Epoch: 7/10.. Validation Loss: 0.040..  Test Accuracy: 0.763
# Epoch: 7/10.. Validation Loss: 0.028..  Test Accuracy: 0.754
# Epoch: 7/10.. Validation Loss: 0.044..  Test Accuracy: 0.761
# Epoch: 7/10.. Validation Loss: 0.036..  Test Accuracy: 0.759
# Epoch: 7/10.. Validation Loss: 0.043..  Test Accuracy: 0.746
# Epoch: 7/10.. Validation Loss: 0.040..  Test Accuracy: 0.745
# Epoch: 8/10.. Validation Loss: 0.054..  Test Accuracy: 0.770
# Epoch: 8/10.. Validation Loss: 0.013..  Test Accuracy: 0.763
# Epoch: 8/10.. Validation Loss: 0.043..  Test Accuracy: 0.768
# Epoch: 8/10.. Validation Loss: 0.033..  Test Accuracy: 0.761
# Epoch: 8/10.. Validation Loss: 0.033..  Test Accuracy: 0.750
# Epoch: 8/10.. Validation Loss: 0.047..  Test Accuracy: 0.725
# Epoch: 8/10.. Validation Loss: 0.042..  Test Accuracy: 0.746
# Epoch: 8/10.. Validation Loss: 0.014..  Test Accuracy: 0.759
# Epoch: 8/10.. Validation Loss: 0.039..  Test Accuracy: 0.769
# Epoch: 8/10.. Validation Loss: 0.042..  Test Accuracy: 0.767
# Epoch: 8/10.. Validation Loss: 0.031..  Test Accuracy: 0.762
# Epoch: 8/10.. Validation Loss: 0.021..  Test Accuracy: 0.768
# Epoch: 8/10.. Validation Loss: 0.023..  Test Accuracy: 0.766
# Epoch: 8/10.. Validation Loss: 0.038..  Test Accuracy: 0.748
# Epoch: 8/10.. Validation Loss: 0.034..  Test Accuracy: 0.741
# Epoch: 8/10.. Validation Loss: 0.069..  Test Accuracy: 0.752
# Epoch: 8/10.. Validation Loss: 0.024..  Test Accuracy: 0.754
# Epoch: 8/10.. Validation Loss: 0.022..  Test Accuracy: 0.743
# Epoch: 8/10.. Validation Loss: 0.029..  Test Accuracy: 0.751
# Epoch: 8/10.. Validation Loss: 0.051..  Test Accuracy: 0.757
# Epoch: 8/10.. Validation Loss: 0.042..  Test Accuracy: 0.749
# Epoch: 8/10.. Validation Loss: 0.024..  Test Accuracy: 0.753
# Epoch: 8/10.. Validation Loss: 0.021..  Test Accuracy: 0.766
# Epoch: 8/10.. Validation Loss: 0.046..  Test Accuracy: 0.759
# Epoch: 8/10.. Validation Loss: 0.072..  Test Accuracy: 0.758
# Epoch: 8/10.. Validation Loss: 0.047..  Test Accuracy: 0.746
# Epoch: 8/10.. Validation Loss: 0.048..  Test Accuracy: 0.753
# Epoch: 8/10.. Validation Loss: 0.062..  Test Accuracy: 0.769
# Epoch: 8/10.. Validation Loss: 0.047..  Test Accuracy: 0.774
# Epoch: 8/10.. Validation Loss: 0.030..  Test Accuracy: 0.759
# Epoch: 8/10.. Validation Loss: 0.057..  Test Accuracy: 0.750
# Epoch: 8/10.. Validation Loss: 0.036..  Test Accuracy: 0.769
# Epoch: 8/10.. Validation Loss: 0.028..  Test Accuracy: 0.761
# Epoch: 8/10.. Validation Loss: 0.063..  Test Accuracy: 0.779
# Epoch: 8/10.. Validation Loss: 0.059..  Test Accuracy: 0.773
# Epoch: 8/10.. Validation Loss: 0.036..  Test Accuracy: 0.769
# Epoch: 8/10.. Validation Loss: 0.022..  Test Accuracy: 0.764
# Epoch: 8/10.. Validation Loss: 0.031..  Test Accuracy: 0.759
# Epoch: 8/10.. Validation Loss: 0.022..  Test Accuracy: 0.774
# Epoch: 8/10.. Validation Loss: 0.025..  Test Accuracy: 0.786
# Epoch: 8/10.. Validation Loss: 0.036..  Test Accuracy: 0.789
# Epoch: 9/10.. Validation Loss: 0.053..  Test Accuracy: 0.788
# Epoch: 9/10.. Validation Loss: 0.025..  Test Accuracy: 0.784
# Epoch: 9/10.. Validation Loss: 0.021..  Test Accuracy: 0.771
# Epoch: 9/10.. Validation Loss: 0.035..  Test Accuracy: 0.762
# Epoch: 9/10.. Validation Loss: 0.028..  Test Accuracy: 0.764
# Epoch: 9/10.. Validation Loss: 0.031..  Test Accuracy: 0.772
# Epoch: 9/10.. Validation Loss: 0.044..  Test Accuracy: 0.775
# Epoch: 9/10.. Validation Loss: 0.031..  Test Accuracy: 0.776
# Epoch: 9/10.. Validation Loss: 0.208..  Test Accuracy: 0.777
# Epoch: 9/10.. Validation Loss: 0.024..  Test Accuracy: 0.779
# Epoch: 9/10.. Validation Loss: 0.042..  Test Accuracy: 0.787
# Epoch: 9/10.. Validation Loss: 0.037..  Test Accuracy: 0.792
# Epoch: 9/10.. Validation Loss: 0.202..  Test Accuracy: 0.774
# Epoch: 9/10.. Validation Loss: 0.025..  Test Accuracy: 0.771
# Epoch: 9/10.. Validation Loss: 0.040..  Test Accuracy: 0.792
# Epoch: 9/10.. Validation Loss: 0.025..  Test Accuracy: 0.810
# Epoch: 9/10.. Validation Loss: 0.029..  Test Accuracy: 0.801
# Epoch: 9/10.. Validation Loss: 0.031..  Test Accuracy: 0.800
# Epoch: 9/10.. Validation Loss: 0.030..  Test Accuracy: 0.789
# Epoch: 9/10.. Validation Loss: 0.036..  Test Accuracy: 0.794
# Epoch: 9/10.. Validation Loss: 0.037..  Test Accuracy: 0.776
# Epoch: 9/10.. Validation Loss: 0.025..  Test Accuracy: 0.775
# Epoch: 9/10.. Validation Loss: 0.020..  Test Accuracy: 0.767
# Epoch: 9/10.. Validation Loss: 0.041..  Test Accuracy: 0.784
# Epoch: 9/10.. Validation Loss: 0.022..  Test Accuracy: 0.783
# Epoch: 9/10.. Validation Loss: 0.013..  Test Accuracy: 0.796
# Epoch: 9/10.. Validation Loss: 0.028..  Test Accuracy: 0.806
# Epoch: 9/10.. Validation Loss: 0.019..  Test Accuracy: 0.795
# Epoch: 9/10.. Validation Loss: 0.026..  Test Accuracy: 0.789
# Epoch: 9/10.. Validation Loss: 0.019..  Test Accuracy: 0.772
# Epoch: 9/10.. Validation Loss: 0.034..  Test Accuracy: 0.766
# Epoch: 9/10.. Validation Loss: 0.028..  Test Accuracy: 0.776
# Epoch: 9/10.. Validation Loss: 0.052..  Test Accuracy: 0.782
# Epoch: 9/10.. Validation Loss: 0.036..  Test Accuracy: 0.774
# Epoch: 9/10.. Validation Loss: 0.022..  Test Accuracy: 0.775
# Epoch: 9/10.. Validation Loss: 0.025..  Test Accuracy: 0.773
# Epoch: 9/10.. Validation Loss: 0.036..  Test Accuracy: 0.776
# Epoch: 9/10.. Validation Loss: 0.039..  Test Accuracy: 0.776
# Epoch: 9/10.. Validation Loss: 0.030..  Test Accuracy: 0.785
# Epoch: 9/10.. Validation Loss: 0.035..  Test Accuracy: 0.778
# Epoch: 9/10.. Validation Loss: 0.021..  Test Accuracy: 0.784
# Epoch: 10/10.. Validation Loss: 0.025..  Test Accuracy: 0.790
# Epoch: 10/10.. Validation Loss: 0.016..  Test Accuracy: 0.786
# Epoch: 10/10.. Validation Loss: 0.013..  Test Accuracy: 0.794
# Epoch: 10/10.. Validation Loss: 0.044..  Test Accuracy: 0.790
# Epoch: 10/10.. Validation Loss: 0.009..  Test Accuracy: 0.793
# Epoch: 10/10.. Validation Loss: 0.019..  Test Accuracy: 0.802
# Epoch: 10/10.. Validation Loss: 0.045..  Test Accuracy: 0.782
# Epoch: 10/10.. Validation Loss: 0.025..  Test Accuracy: 0.776
# Epoch: 10/10.. Validation Loss: 0.047..  Test Accuracy: 0.780
# Epoch: 10/10.. Validation Loss: 0.027..  Test Accuracy: 0.796
# Epoch: 10/10.. Validation Loss: 0.042..  Test Accuracy: 0.788
# Epoch: 10/10.. Validation Loss: 0.004..  Test Accuracy: 0.791
# Epoch: 10/10.. Validation Loss: 0.044..  Test Accuracy: 0.780
# Epoch: 10/10.. Validation Loss: 0.047..  Test Accuracy: 0.793
# Epoch: 10/10.. Validation Loss: 0.021..  Test Accuracy: 0.810
# Epoch: 10/10.. Validation Loss: 0.028..  Test Accuracy: 0.802
# Epoch: 10/10.. Validation Loss: 0.034..  Test Accuracy: 0.813
# Epoch: 10/10.. Validation Loss: 0.022..  Test Accuracy: 0.808
# Epoch: 10/10.. Validation Loss: 0.051..  Test Accuracy: 0.794
# Epoch: 10/10.. Validation Loss: 0.042..  Test Accuracy: 0.793
# Epoch: 10/10.. Validation Loss: 0.037..  Test Accuracy: 0.805
# Epoch: 10/10.. Validation Loss: 0.028..  Test Accuracy: 0.805
# Epoch: 10/10.. Validation Loss: 0.040..  Test Accuracy: 0.795
# Epoch: 10/10.. Validation Loss: 0.032..  Test Accuracy: 0.811
# Epoch: 10/10.. Validation Loss: 0.004..  Test Accuracy: 0.810
# Epoch: 10/10.. Validation Loss: 0.200..  Test Accuracy: 0.801
# Epoch: 10/10.. Validation Loss: 0.023..  Test Accuracy: 0.808
# Epoch: 10/10.. Validation Loss: 0.056..  Test Accuracy: 0.800
# Epoch: 10/10.. Validation Loss: 0.024..  Test Accuracy: 0.802
# Epoch: 10/10.. Validation Loss: 0.016..  Test Accuracy: 0.801
# Epoch: 10/10.. Validation Loss: 0.027..  Test Accuracy: 0.806
# Epoch: 10/10.. Validation Loss: 0.040..  Test Accuracy: 0.809
# Epoch: 10/10.. Validation Loss: 0.032..  Test Accuracy: 0.823
# Epoch: 10/10.. Validation Loss: 0.197..  Test Accuracy: 0.815
# Epoch: 10/10.. Validation Loss: 0.038..  Test Accuracy: 0.800
# Epoch: 10/10.. Validation Loss: 0.026..  Test Accuracy: 0.797
# Epoch: 10/10.. Validation Loss: 0.016..  Test Accuracy: 0.805
# Epoch: 10/10.. Validation Loss: 0.025..  Test Accuracy: 0.801
# Epoch: 10/10.. Validation Loss: 0.034..  Test Accuracy: 0.798
# Epoch: 10/10.. Validation Loss: 0.044..  Test Accuracy: 0.793
# Epoch: 10/10.. Validation Loss: 0.028..  Test Accuracy: 0.784
# Done training!
# 02:30:27.77
# Checkpoint saved!

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Done: Do validation on the test set
accuracy = 0

with torch.no_grad():
    for images, labels in dataloaders['test_loader']:
        
        model = model.to('cuda')
        labels = labels.to('cuda')
        images = images.to('cuda')

        outputs = model(images) 
    
        ps = torch.exp(outputs)
        equality = (labels.data == ps.max(dim=1)[1])
        accuracy = equality.type(torch.FloatTensor).mean()

accuracy
# Out:
# tensor(0.8421)

# %% [markdown]
# # Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Done: Save the checkpoint 
checkpoint = {'input_size': 25088,
              'output_size': 102,
              'hidden_layers': [2304, 1224, 684, 302],
              'model_class_to_idx': image_datasets['train_data'].class_to_idx,
              'state_dict': model.state_dict()}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Done: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    
    hidden_layers = checkpoint['hidden_layers']
    
    # Load a pretrained network.
    model = models.vgg16(pretrained=True)

    # Freeze parameters
    for param in model.parameters():
        param.requires_grad = False

    # Build a feed-forward network
    classifier = nn.Sequential(
                 nn.Linear(checkpoint['input_size'], hidden_layers[0]),
                 nn.ReLU(),
                 nn.Dropout(0.3),
                 nn.Linear(hidden_layers[0], hidden_layers[1]),
                 nn.ReLU(),
                 nn.Dropout(0.3),
                 nn.Linear(hidden_layers[1], hidden_layers[2]),
                 nn.ReLU(),
                 nn.Dropout(0.3),
                 nn.Linear(hidden_layers[2], hidden_layers[3]),
                 nn.ReLU(),
                 nn.Dropout(0.3),
                 nn.Linear(hidden_layers[3], checkpoint['output_size']),
                 nn.LogSoftmax(dim=1))


    model.classifier = classifier
    
    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_idx = checkpoint['model_class_to_idx']
    
    return model

model = load_checkpoint('checkpoint.pth')
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:32<00:00, 17007219.71it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=2304, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3)
#     (3): Linear(in_features=2304, out_features=1224, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3)
#     (6): Linear(in_features=1224, out_features=684, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.3)
#     (9): Linear(in_features=684, out_features=302, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.3)
#     (12): Linear(in_features=302, out_features=102, bias=True)
#     (13): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    pil_img = Image.open(image)
    img_mod = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])])
    
    np_image = img_mod(pil_img)

    return np_image

# TODO: Process a PIL image for use in a PyTorch model

image = (data_dir + '/test' +'/1/'+ 'image_06764.jpg')

image = process_image(image)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image(data_dir + '/test' +'/1/'+ 'image_06764.jpg'))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    model.to('cuda')
    image=  Variable(torch.FloatTensor(image), requires_grad=True)
    image = image.unsqueeze(0) #for VGG
    image = image.cuda()
    result = model(image).topk(topk)
    probs = torch.nn.functional.softmax(result[0].data, dim=1).cpu().numpy()[0]
    classes = result[1].data.cpu().numpy()[0]
    idx_to_class = { v : k for k,v in model.class_to_idx.items()}
    topk_class = [idx_to_class[x] for x in classes]


    return probs, topk_class

    
# TODO: Implement the code to predict the class from an image file

img = (data_dir + '/test' + '/15/' + 'image_06351.jpg')
probs, classes = predict(process_image(img), model)
print(probs)
print(classes)
# Out:
# [ 0.55294323  0.24507494  0.09318106  0.06902232  0.03977849]
# ['61', '8', '99', '15', '24']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes'
image_path = (data_dir + '/test' +'/1/'+ 'image_06764.jpg')

image = process_image(image_path)
probabilities, classes = predict(image, model)

f_names = [cat_to_name [name] for name in classes]

image = Image.open(image_path)

_, ax = plt.subplots(2,figsize = (6,10))

ax[0].imshow(image)
ax[0].set_title(names[0])

y_names = np.arange(len(f_names))
ax[1].barh(y_names, probabilities, color='green')
ax[1].set_yticks(y_names)
ax[1].set_yticklabels(f_names)
ax[1].invert_yaxis() 

plt.show()
